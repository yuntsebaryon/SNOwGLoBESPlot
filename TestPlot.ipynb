# %%
# import necessary package
import numpy as np
import matplotlib.pyplot as plt

# %%
inDir = '/Users/yuntse/work/supernova/SNOwGLoBES/out/'

# %%
inFile = inDir + '/livermore_nue_e_ar40kt_DCR_THR35QENonRefl2PE_events_smeared.dat'
flux = np.genfromtxt(inFile, skip_footer=2)

# %%
flux
# Out:
# array([[7.4880000e-04, 2.4241140e+00],
#        [1.2460000e-03, 3.0376800e+00],
#        [1.7440000e-03, 4.0299840e+00],
#        [2.2410000e-03, 5.1188400e+00],
#        [2.7390000e-03, 6.0761160e+00],
#        [3.2360000e-03, 6.8278320e+00],
#        [3.7340000e-03, 7.3796580e+00],
#        [4.2310000e-03, 7.7749740e+00],
#        [4.7290000e-03, 8.0717580e+00],
#        [5.2260000e-03, 8.2799640e+00],
#        [5.7240000e-03, 8.3888640e+00],
#        [6.2210000e-03, 8.4615840e+00],
#        [6.7190000e-03, 8.5327020e+00],
#        [7.2160000e-03, 8.5318200e+00],
#        [7.7140000e-03, 8.4599640e+00],
#        [8.2110000e-03, 8.3542680e+00],
#        [8.7090000e-03, 8.1987300e+00],
#        [9.2060000e-03, 7.9905240e+00],
#        [9.7040000e-03, 7.8296040e+00],
#        [1.0200000e-02, 7.7016600e+00],
#        [1.0700000e-02, 7.4804580e+00],
#        [1.1200000e-02, 7.1857080e+00],
#        [1.1690000e-02, 6.9020280e+00],
#        [1.2190000e-02, 6.6718800e+00],
# ...

# %%
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.plot(flux[:,0], flux[:,1], linewidth = 2)
plt.xlabel('Energy [GeV]', fontsize=20)
plt.ylabel('Event Rate', fontsize=20)
plt.show()
